# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#! git clone https://github.com/oadams/latticetm.git 
#! git clone https://github.com/neubig/latticetm.git
! ls
! git clone https://github.com/brendon-boldt/latticetm.git
# %cd latticetm/ 
#! git fetch origin pull/1/head
#! git checkout -b pullrequest FETCH_HEAD
! git branch -a
#! git checkout update-dependencies
#!git branch -a
# Out:
# gdrive	sample_data
# Cloning into 'latticetm'...
# remote: Enumerating objects: 973, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 973 (delta 4), reused 6 (delta 4), pack-reused 953
# Receiving objects: 100% (973/973), 195.23 KiB | 2.96 MiB/s, done.
# Resolving deltas: 100% (657/657), done.
# /content/latticetm
# * master
#   remotes/origin/HEAD -> origin/master
#   remotes/origin/ctc
#   remotes/origin/master

# %%
! git pull
# Out:
# Already up to date.

# %%
# !cp -r ../gdrive/MyDrive/spanish_english_data/ .

# %%
# getting real data 
# !cp gdrive/MyDrive/real_data.tgz .
# Out:
# cp: cannot stat 'gdrive/MyDrive/real_data.tgz': No such file or directory

# %%
# !sudo apt-get install AutoTools libtool libboost-all-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package AutoTools

# %%
# !wget https://www.openfst.org/twiki/pub/FST/FstDownload/openfst-1.8.1.tar.gz
# !tar -xvf openfst-1.8.1.tar.gz
# Out:
# --2021-11-12 02:37:43--  https://www.openfst.org/twiki/pub/FST/FstDownload/openfst-1.8.1.tar.gz
# Resolving www.openfst.org (www.openfst.org)... 206.196.111.47
# Connecting to www.openfst.org (www.openfst.org)|206.196.111.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1333532 (1.3M) [application/x-gzip]
# Saving to: ‘openfst-1.8.1.tar.gz’
#
# openfst-1.8.1.tar.g 100%[===================>]   1.27M  5.53MB/s    in 0.2s
#
# 2021-11-12 02:37:43 (5.53 MB/s) - ‘openfst-1.8.1.tar.gz’ saved [1333532/1333532]
#
# openfst-1.8.1/
# openfst-1.8.1/AUTHORS
# openfst-1.8.1/depcomp
# openfst-1.8.1/COPYING
# openfst-1.8.1/config.sub
# openfst-1.8.1/.bazelrc
# openfst-1.8.1/ar-lib
# openfst-1.8.1/NEWS
# openfst-1.8.1/install-sh
# openfst-1.8.1/BUILD.bazel
# openfst-1.8.1/missing
# openfst-1.8.1/README
# openfst-1.8.1/config.guess
# openfst-1.8.1/configure
# openfst-1.8.1/WORKSPACE.bazel
# openfst-1.8.1/Makefile.am
# openfst-1.8.1/aclocal.m4
# ...

# %%
# %cd openfst-1.8.1
# Out:
# /content/latticetm/openfst-1.8.1

# %%
# !ls
# Out:
# aclocal.m4   config.guess  COPYING     m4	    README
# ar-lib	     config.h.in   depcomp     Makefile.am  src
# AUTHORS      config.sub    INSTALL     Makefile.in  test-driver
# BUILD.bazel  configure	   install-sh  missing	    WORKSPACE.bazel
# compile      configure.ac  ltmain.sh   NEWS

# %%
# !sudo apt-get install automake
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   autoconf autotools-dev libsigsegv2 m4
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc libtool gettext m4-doc
# The following NEW packages will be installed:
#   autoconf automake autotools-dev libsigsegv2 m4
# 0 upgraded, 5 newly installed, 0 to remove and 37 not upgraded.
# Need to get 1,082 kB of archives.
# After this operation, 3,994 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# ...

# %%
# !sudo apt-get install libtool m4 automake
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# automake is already the newest version (1:1.15.1-3ubuntu2).
# m4 is already the newest version (1.4.18-1).
# m4 set to manually installed.
# The following additional packages will be installed:
#   file libmagic-mgc libmagic1
# Suggested packages:
#   libtool-doc gcj-jdk
# The following NEW packages will be installed:
#   file libmagic-mgc libmagic1 libtool
# 0 upgraded, 4 newly installed, 0 to remove and 37 not upgraded.
# Need to get 468 kB of archives.
# After this operation, 6,555 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# ...

# %%
# !autoreconf -f -i
# Out:
# libtoolize: putting auxiliary files in '.'.
# libtoolize: copying file './ltmain.sh'
# libtoolize: putting macros in AC_CONFIG_MACRO_DIRS, 'm4'.
# libtoolize: copying file 'm4/libtool.m4'
# libtoolize: copying file 'm4/ltoptions.m4'
# libtoolize: copying file 'm4/ltsugar.m4'
# libtoolize: copying file 'm4/ltversion.m4'
# libtoolize: copying file 'm4/lt~obsolete.m4'
# configure.ac:3: installing './compile'
# configure.ac:2: installing './missing'
# src/bin/Makefile.am: installing './depcomp'

# %%
# !apt-get install cuda gcc-8 g++-8 -y -qq;
# Out:
# Extracting templates from packages: 100%
# Selecting previously unselected package cpp-8.
# (Reading database ... 155561 files and directories currently installed.)
# Preparing to unpack .../00-cpp-8_8.4.0-1ubuntu1~18.04_amd64.deb ...
# Unpacking cpp-8 (8.4.0-1ubuntu1~18.04) ...
# Selecting previously unselected package cuda-toolkit-config-common.
# Preparing to unpack .../01-cuda-toolkit-config-common_11.5.50-1_all.deb ...
# Unpacking cuda-toolkit-config-common (11.5.50-1) ...
# Selecting previously unselected package cuda-toolkit-11-config-common.
# Preparing to unpack .../02-cuda-toolkit-11-config-common_11.5.50-1_all.deb ...
# Unpacking cuda-toolkit-11-config-common (11.5.50-1) ...
# Selecting previously unselected package cuda-toolkit-11-5-config-common.
# Preparing to unpack .../03-cuda-toolkit-11-5-config-common_11.5.50-1_all.deb ...
# Unpacking cuda-toolkit-11-5-config-common (11.5.50-1) ...
# Selecting previously unselected package cuda-cudart-11-5.
# ...

# %%
# !chmod 755 configure
# !CXXFLAGS="-g -O2 -std=c++17" CC=gcc-8 CXX=g++-8 ./configure
# Out:
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for style of include used by make... GNU
# checking for gcc... gcc-8
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc-8 accepts -g... yes
# checking for gcc-8 option to accept ISO C89... none needed
# checking whether gcc-8 understands -c and -o together... yes
# checking dependency style of gcc-8... gcc3
# checking for ar... ar
# checking the archiver (ar) interface... ar
# ...

# %%
# !make
# Out:
# make  all-recursive
# make[1]: Entering directory '/content/latticetm/openfst-1.8.1'
# Making all in src
# make[2]: Entering directory '/content/latticetm/openfst-1.8.1/src'
# Making all in include
# make[3]: Entering directory '/content/latticetm/openfst-1.8.1/src/include'
# make[3]: Nothing to be done for 'all'.
# make[3]: Leaving directory '/content/latticetm/openfst-1.8.1/src/include'
# Making all in lib
# make[3]: Entering directory '/content/latticetm/openfst-1.8.1/src/lib'
# depbase=`echo compat.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ../../libtool  --tag=CXX   --mode=compile g++-8 -std=c++17 -fno-exceptions -Wno-deprecated-declarations -DHAVE_CONFIG_H   -I./../include    -g -O2 -std=c++17 -MT compat.lo -MD -MP -MF $depbase.Tpo -c -o compat.lo compat.cc &&\
# mv -f $depbase.Tpo $depbase.Plo
# ...

# %%
# !sudo make install
# Out:
# Making install in src
# make[1]: Entering directory '/content/latticetm/openfst-1.8.1/src'
# Making install in include
# make[2]: Entering directory '/content/latticetm/openfst-1.8.1/src/include'
# make[3]: Entering directory '/content/latticetm/openfst-1.8.1/src/include'
# make[3]: Nothing to be done for 'install-exec-am'.
#  /bin/mkdir -p '/usr/local/include'
#  /bin/mkdir -p '/usr/local/include/fst'
# ...

# %%
# !pwd
# !ls
# %cd ../latticetm/
# Out:
# /content/latticetm/openfst-1.8.1
# aclocal.m4	config.h       configure.ac  m4		  src
# ar-lib		config.h.in    COPYING	     Makefile	  stamp-h1
# AUTHORS		config.h.in~   depcomp	     Makefile.am  test-driver
# autom4te.cache	config.log     INSTALL	     Makefile.in  WORKSPACE.bazel
# BUILD.bazel	config.status  install-sh    missing
# compile		config.sub     libtool	     NEWS
# config.guess	configure      ltmain.sh     README
# [Errno 2] No such file or directory: '../latticetm/'
# /content/latticetm/openfst-1.8.1

# %%
# !ls
# Out:
# aclocal.m4	config.h       configure.ac  m4		  src
# ar-lib		config.h.in    COPYING	     Makefile	  stamp-h1
# AUTHORS		config.h.in~   depcomp	     Makefile.am  test-driver
# autom4te.cache	config.log     INSTALL	     Makefile.in  WORKSPACE.bazel
# BUILD.bazel	config.status  install-sh    missing
# compile		config.sub     libtool	     NEWS
# config.guess	configure      ltmain.sh     README

# %%
# !autoreconf -f -i
# Out:
# libtoolize: putting auxiliary files in '.'.
# libtoolize: copying file './ltmain.sh'
# libtoolize: putting macros in AC_CONFIG_MACRO_DIRS, 'm4'.
# libtoolize: copying file 'm4/libtool.m4'
# libtoolize: copying file 'm4/ltoptions.m4'
# libtoolize: copying file 'm4/ltsugar.m4'
# libtoolize: copying file 'm4/ltversion.m4'
# libtoolize: copying file 'm4/lt~obsolete.m4'
# configure.ac:3: installing './compile'
# configure.ac:2: installing './missing'
# src/bin/Makefile.am: installing './depcomp'

# %%
! git branch -a
# !CXXFLAGS="-g -O2 -std=c++17" CC=gcc-8 CXX=g++-8 ./configure --with-openfst=/content/openfst-1.8.1
# Out:
# * master
#   remotes/origin/HEAD -> origin/master
#   remotes/origin/ctc
#   remotes/origin/master
# configure: WARNING: unrecognized options: --with-openfst
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for style of include used by make... GNU
# checking for gcc... gcc-8
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc-8 accepts -g... yes
# checking for gcc-8 option to accept ISO C89... none needed
# ...

# %%
# CHANGE LATTICELM
# !make
# Out:
# Making all in src
# make[1]: Entering directory '/content/latticetm/src'
# Making all in latticelm
# make[2]: Entering directory '/content/latticetm/src/latticelm'
# make  all-am
# make[3]: Entering directory '/content/latticetm/src/latticelm'
# depbase=`echo latticelm.lo | sed 's|[^/]*$|.deps/&|;s|\.lo$||'`;\
# /bin/bash ../../libtool  --tag=CXX   --mode=compile g++-8 -DHAVE_CONFIG_H -I.   -I/content/openfst-1.8.1/src/include -I/usr/include -I./.. -g -O2 -std=c++17 -std=c++17 -MT latticelm.lo -MD -MP -MF $depbase.Tpo -c -o latticelm.lo latticelm.cc &&\
# mv -f $depbase.Tpo $depbase.Plo
# libtool: compile:  g++-8 -DHAVE_CONFIG_H -I. -I/content/openfst-1.8.1/src/include -I/usr/include -I./.. -g -O2 -std=c++17 -std=c++17 -MT latticelm.lo -MD -MP -MF .deps/latticelm.Tpo -c latticelm.cc  -fPIC -DPIC -o .libs/latticelm.o
# ...

# %%
! git branch -a
# Out:
# * master
#   remotes/origin/HEAD -> origin/master
#   remotes/origin/ctc
#   remotes/origin/master

# %%
# CHANGE LATTICELM
# %cd /content/latticetm/
# !ls
# !autoreconf -f -i
# !CXXFLAGS="-g -O2 -std=c++17" CC=gcc-8 CXX=g++-8 ./configure --with-openfst=/content/openfst-1.8.1
# !make
# Out:
# /content/latticetm
# aclocal.m4	config.sub    install-sh   openfst-1.8.1	 src
# ar-lib		configure     libtool	   openfst-1.8.1.tar.gz  test-driver
# AUTHORS		configure.ac  ltmain.sh    plain_best_paths	 TODO
# autom4te.cache	COPYING       m4	   README		 valgrindtest
# ChangeLog	data	      Makefile	   README.md		 wer
# compile		decode_giza   Makefile.am  run
# config.guess	depcomp       Makefile.in  run_giza
# config.log	grid_search   missing	   scaling_test
# config.status	INSTALL       NEWS	   spanish_english_data
# libtoolize: putting auxiliary files in '.'.
# libtoolize: copying file './ltmain.sh'
# libtoolize: putting macros in AC_CONFIG_MACRO_DIRS, 'm4'.
# libtoolize: copying file 'm4/libtool.m4'
# libtoolize: copying file 'm4/ltoptions.m4'
# libtoolize: copying file 'm4/ltsugar.m4'
# libtoolize: copying file 'm4/ltversion.m4'
# libtoolize: copying file 'm4/lt~obsolete.m4'
# configure.ac:16: installing './compile'
# configure.ac:15: installing './missing'
# ...

# %%
# !ls spanish_english_data/
# Out:
# fisher_dev_300.es.lat  fisher_dev.en.0.nopunc.lower  fisher_dev.es.lat

# %%
# !ls
# Out:
# aclocal.m4	config.sub    install-sh   openfst-1.8.1	 src
# ar-lib		configure     libtool	   openfst-1.8.1.tar.gz  test-driver
# AUTHORS		configure.ac  ltmain.sh    plain_best_paths	 TODO
# autom4te.cache	COPYING       m4	   README		 valgrindtest
# ChangeLog	data	      Makefile	   README.md		 wer
# compile		decode_giza   Makefile.am  run
# config.guess	depcomp       Makefile.in  run_giza
# config.log	grid_search   missing	   scaling_test
# config.status	INSTALL       NEWS	   spanish_english_data

# %%
# !sudo ldconfig
# Out:
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# !./src/latticelm/latticelm \
  --train_file spanish_english_data/fisher_dev.es.lat --trans_file spanish_english_data/fisher_dev.en.0.nopunc.lower \
  --file_format openfst --model_type lextm \
  --epochs 5 --concentration 1 --lattice_weight 1 \
  --train_len 2250 --test_len 250 \
  --prior pmp --starters 0.00001 --gamma 0.75 --seed 4 \
  --outfile ./data/output.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# time: 216.522
#
# align 584, align_id: 584
# time: 216.538
#
# align 585, align_id: 585
# time: 216.55
#
# align 586, align_id: 586
# time: 216.605
#
# align 587, align_id: 587
# time: 216.623
#
# align 588, align_id: 588
# time: 216.657
#
# align 589, align_id: 589
# time: 216.669
#
# align 590, align_id: 590
# time: 216.697
#
# align 591, align_id: 591
# time: 216.707
#
# align 592, align_id: 592
# time: 216.757
#
# align 593, align_id: 593
# time: 216.769
#
# align 594, align_id: 594
# time: 216.785
#
# align 595, align_id: 595
# time: 216.799
#
# align 596, align_id: 596
# time: 216.827
#
# align 597, align_id: 597
# time: 216.841
#
# align 598, align_id: 598
# time: 216.866
#
# align 599, align_id: 599
# time: 216.883
#
# align 600, align_id: 600
# time: 216.996
#
# align 601, align_id: 601
# time: 217.025
#
# align 602, align_id: 602
# time: 217.037
#
# align 603, align_id: 603
# time: 217.073
#
# align 604, align_id: 604
# ...

# %%
# !./src/latticelm/latticelm \
  --train_file spanish_english_data/fisher_dev.es.lat --trans_file spanish_english_data/fisher_dev.en.0.nopunc.lower \
  --file_format openfst --model_type lextm \
  --epochs 10 --concentration 1 --lattice_weight 1 \
  --train_len 3000 --test_len 500 \
  --prior pmp --starters 0.00001 --gamma 0.75 --seed 4 \
  --outfile ./data/output.txt
# Out:
# Streaming output truncated to the last 5000 lines.
#
# align 1334, align_id: 1826
# time: 1830.32
#
# align 1335, align_id: 1535
# time: 1830.35
#
# align 1336, align_id: 272
# time: 1830.53
#
# align 1337, align_id: 1308
# time: 1830.6
#
# align 1338, align_id: 1675
# time: 1830.63
#
# align 1339, align_id: 1225
# time: 1830.82
#
# align 1340, align_id: 1565
# time: 1830.91
#
# align 1341, align_id: 704
# time: 1830.95
#
# align 1342, align_id: 2020
# time: 1830.99
#
# align 1343, align_id: 615
# time: 1831.03
#
# align 1344, align_id: 2841
# time: 1831.11
#
# align 1345, align_id: 233
# time: 1831.16
#
# align 1346, align_id: 2863
# time: 1831.18
#
# align 1347, align_id: 259
# time: 1831.47
#
# align 1348, align_id: 2087
# time: 1831.56
#
# align 1349, align_id: 1171
# time: 1831.59
#
# align 1350, align_id: 2724
# time: 1831.66
#
# align 1351, align_id: 1887
# time: 1831.69
#
# align 1352, align_id: 961
# time: 1831.73
#
# align 1353, align_id: 1533
# time: 1831.75
#
# ...
